# %% [markdown]
# # The Sparks Foundation
# ## Graduate Rotational Internship Program (GRIP)
# ### Data Science &Business Analytics Internship
# ### Auther : Shraddha Tarawade
# ## Task 3 - Exploratory Data Analysis-Retail
# ### Problem statement: Perform 'Exploratory Data Analysis' on dataset 'SampleSuperStore'
#     Data set : https://bit.ly/3i4rbWl

# %% [markdown]
# ### 1.  Importing the required libraries and Data

# %%
#First we import all the libraries that we need 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# sets the backend of matplotlib to the 'inline' backend
#to display inline within frontends like the Jupyter notebook

# %%
data=pd.read_csv('C:\\Users\shrad\Desktop\Data Science\SparkFoundation\Task3\SampleSuperstore.csv')
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %% [markdown]
# ### 2. Visualisng the data

# %%
# data.info() gives Consize memmory of data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
# data.tail(n) gives last n rows from the data
data.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
# data.isnull().sum() gives count of missing values present in each column
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
# data.describe() gives statistical properties of the data
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
# data.shape gives number of rows and columns in the data
data.shape
# Out:
# (9994, 13)

# %%
# data.corr() is used to find the pairwise correlation of all columns in the dataframe.
data.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
# data.nunique() gives the number of unique values for each column of data
data.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
# data.columns gives column names 
data.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
# data.sample() gives  particular length list of items chosen from the sequence i.e. list, tuple, string or set
data.sample(5)
# Out:
#            Ship Mode    Segment        Country         City       State  \
# 2622    Second Class  Corporate  United States  Saint Louis    Missouri
# 4867  Standard Class   Consumer  United States      Seattle  Washington
# 7543  Standard Class  Corporate  United States       Denver    Colorado
# 7455  Standard Class   Consumer  United States      Chicago    Illinois
# 1884    Second Class   Consumer  United States       Keller       Texas
#
#       Postal Code   Region         Category Sub-Category     Sales  Quantity  \
# 2622        63116  Central  Office Supplies        Paper    25.920         4
# 4867        98103     West  Office Supplies      Storage   344.910         3
# 7543        80219     West       Technology       Phones    57.360         6
# 7455        60623  Central  Office Supplies      Storage  1036.624         2
# 1884        76248  Central  Office Supplies       Labels     6.000         2
#
#       Discount   Profit
# 2622       0.0  12.4416
# ...

# %%
#Checking fot the number of duplicate values
data.duplicated().sum()
# Out:
# 17

# %%
# data.drop_duplicates() drops duplicate values
data.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
#Dropping the Postal Code columns as it serves no purpose
data.drop(columns="Postal Code", axis=1, inplace=True)

# %% [markdown]
# ### 3. Plots

# %%
# The heat maps shows the correlation between the entities
corelation = data.corr()
sns.heatmap(corelation,xticklabels=corelation.columns, yticklabels=corelation.columns,annot=True,cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (10,5))
sns.countplot(x=data['Segment'])
plt.show()

# %%
sns.countplot(x=data['Region'])
# Out:
# <AxesSubplot:xlabel='Region', ylabel='count'>

# %%
sns.countplot(x=data['Category'], data=data)
# Out:
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %%
plt.figure(figsize = (15,7))
sns.countplot(x = data['Sub-Category'],data=data)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,15))
sns.barplot(x=data['Sub-Category'], y=data['Profit'])
# Out:
# <AxesSubplot:xlabel='Sub-Category', ylabel='Profit'>

# %%
#Relation between profit and dicount
plt.figure(figsize = (15,7))
sns.lineplot('Discount', 'Profit', data = data, color = 'r', label= 'Discount')
plt.legend()
# Out:
# C:\Users\shrad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data.hist(bins=40 ,figsize=(20,15))
plt.show()

# %%
# pairplot function will create a grid of Axes such that each numeric variable in data will by shared across the y-axes and x
figsize=(20,5)
sns.pairplot(data,hue='Sub-Category')

# %%
figsize=(20,5)
sns.pairplot(data,hue='Category')

# %%
figsize=(20,5)
sns.pairplot(data,hue='Segment')

# %%
figsize=(20,5)
sns.pairplot(data, hue="Region")

# %% [markdown]
# ### 4. Preferred Shipping Mode

# %%
data["Ship Mode"].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
sns.histplot(x=data["Ship Mode"])
plt.title("Ship Mode Classification")
# Out:
# Text(0.5, 1.0, 'Ship Mode Classification')

# %% [markdown]
# ### 5. Customer Segments

# %%
data["Segment"].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
sns.histplot(x=data["Segment"])
plt.title("Segment Classification")
# Out:
# Text(0.5, 1.0, 'Segment Classification')

# %%
plt.figure(figsize=(4,4))
plt.pie(data["Category"].value_counts(),labels=data["Category"].value_counts().index,autopct="%1.1f%%")
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.pie(data["Sub-Category"].value_counts(),labels=data["Sub-Category"].value_counts().index,autopct="%1.1f%%")
plt.show()

# %%
sns.countplot(x=data["Region"],hue=data["Category"])
# Out:
# <AxesSubplot:xlabel='Region', ylabel='count'>

# %%
plt.figure(figsize=(8,8))
data.groupby("Category")["Profit","Sales"].agg("sum").plot.bar()
plt.show()
# Out:
# <ipython-input-85-8b1508a40fcd>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby("Category")["Profit","Sales"].agg("sum").plot.bar()

# %%
plt.figure(figsize=(8,8))
data.groupby("Sub-Category")["Profit","Sales"].agg("sum").plot.bar()
plt.show()
# Out:
# <ipython-input-86-521c4c411643>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby("Sub-Category")["Profit","Sales"].agg("sum").plot.bar()

# %%
plt.figure(figsize=(8,8))
data.groupby("Region")["Profit","Sales"].agg("sum").plot.bar()
plt.show()
# Out:
# <ipython-input-87-aa5c140f8467>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby("Region")["Profit","Sales"].agg("sum").plot.bar()

# %%
data.groupby("State").Profit.agg(["sum","mean","min","max","count","median","std","var"])
# Out:
#                              sum        mean        min        max  count  \
# State
# Alabama                5786.8253   94.865989     0.0000  1459.2000     61
# Arizona               -3427.9246  -15.303235  -814.4832   211.4955    224
# Arkansas               4008.6871   66.811452     1.4190   843.1706     60
# California            76381.3871   38.171608  -325.5720  1906.4850   2001
# Colorado              -6527.8579  -35.867351 -3399.9800   247.9960    182
# Connecticut            3511.4918   42.823071   -15.5826   294.6710     82
# Delaware               9977.3748  103.930988   -48.7839  5039.9856     96
# District of Columbia   1059.5893  105.958930     4.4344   648.5624     10
# Florida               -3399.3017   -8.875461 -1811.0784   327.5922    383
# Georgia               16250.0433   88.315453     0.1134  3177.4750    184
# Idaho                   826.7231   39.367767     1.1151   259.5297     21
# Illinois             -12607.8870  -25.625787 -2929.4845   874.9875    492
# ...

# %%
sales_profit = data.groupby("State")["Profit"].sum()

# %% [markdown]
# ### Heatmap :
#         Profit and sales are highly co-related which means that they have a strong impact on each other.
#         Correlation between quantity and profit is weak,profit is not influenced heavily by the quantity of goods.
#         Sales of Furniture of Category are high,but profits generated are low compared to the office supplies,Tech.
#         Bookcases,tables have higer sales and operating at loss.Limiting the sales would be beneficial.

# %% [markdown]
# ## Conclusion
#      Profit and discount are highly correlated.
#      Mode of shipping is not affecting so much in sales.
#      High discount is to be applied in other segment(exclding in furniture) to improve sales.
#      Sub-categories sales of table should be minimized.
#      Sales should increse in east region as profit is more compare to others.
